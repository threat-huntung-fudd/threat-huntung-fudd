# %% [markdown]
# # download and unzip data files.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path
import logging
import os
import logging
import gdown
import tarfile
# Set system path to the folder where the notebook is saved
notebook_dir = Path().resolve()
sys.path.insert(0, str(notebook_dir))

from cadets import DarpaParser

# Set up logging configuration
logging.basicConfig(
    level=logging.INFO, 
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.StreamHandler(sys.stdout)  # Ensure logs are output to stdout
    ]
)
logger = logging.getLogger(__name__)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def download_data(urls: list[str], save_dir: str):
    logging.info("Executing DownloadData")
    os.makedirs(save_dir, exist_ok=True)  # Ensure save directory exists
    
    for url in urls:
        logging.info(f"Downloading {url}")
        filename = gdown.download(url, quiet=False, use_cookies=False, fuzzy=True)
        
        if filename:
            destination = os.path.join(save_dir, os.path.basename(filename))
            os.rename(filename, destination)
        else:
            logging.warning(f"Failed to download {url}")

# %% [markdown]
# # add links from:
#  - https://github.com/darpa-i2o/Transparent-Computing/blob/master/README-E3.md
#  - or https://drive.google.com/drive/folders/1QlbUFWAGq3Hpl8wVdzOdIoZLFxkII4EK?usp=drive_open
#
#  as urls

# %%
save_dir = "input_data/trace"
# urls: list[str] = ["link1", "link2", "link3"]  # Replace with actual URLs
urls: list[str] = ["https://drive.google.com/file/d/1sfIbavsUFwmB-irSGY1TZZ0Sq1dZqF9G/view?usp=share_link",
"https://drive.google.com/file/d/1GG1aUnPjjzzdbxznVTN8X6oVfA-K4oIV/view?usp=share_link"]

download_data(urls, save_dir)
# Out:
# 2025-05-02 12:19:57,303 - INFO - Executing DownloadData
# 2025-05-02 12:19:57,303 - INFO - Downloading https://drive.google.com/file/d/1sfIbavsUFwmB-irSGY1TZZ0Sq1dZqF9G/view?usp=share_link
# Downloading...
# From (original): https://drive.google.com/uc?id=1sfIbavsUFwmB-irSGY1TZZ0Sq1dZqF9G
# From (redirected): https://drive.google.com/uc?id=1sfIbavsUFwmB-irSGY1TZZ0Sq1dZqF9G&confirm=t&uuid=8b6b2ff7-11e3-44d1-906c-660575994afe
# To: /home/robin/fudd/create_graph/ta1-trace-e3-official.json.tar.gz
# 100%|██████████| 37.1G/37.1G [09:40<00:00, 63.9MB/s]
# 2025-05-02 12:29:42,147 - INFO - Downloading https://drive.google.com/file/d/1GG1aUnPjjzzdbxznVTN8X6oVfA-K4oIV/view?usp=share_link
# Downloading...
# From (original): https://drive.google.com/uc?id=1GG1aUnPjjzzdbxznVTN8X6oVfA-K4oIV
# From (redirected): https://drive.google.com/uc?id=1GG1aUnPjjzzdbxznVTN8X6oVfA-K4oIV&confirm=t&uuid=de32deee-9ce7-4968-a72d-5093f97a665a
# To: /home/robin/fudd/create_graph/ta1-trace-e3-official-1.json.tar.gz
# 100%|██████████| 1.28G/1.28G [00:20<00:00, 62.3MB/s]

# %%
for file in os.listdir(save_dir):
    if file.endswith(".tar.gz"):
        file_path = os.path.join(save_dir, file)
        with tarfile.open(file_path, "r:gz") as tar:
            tar.extractall(path=save_dir)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 5
#       3 file_path = os.path.join(save_dir, file)
#       4 with tarfile.open(file_path, "r:gz") as tar:
# ----> 5     tar.extractall(path=save_dir)
#
# File ~/anaconda3/envs/tgb_env/lib/python3.9/tarfile.py:2279, in TarFile.extractall(self, path, members, numeric_owner, filter)
#    2274     if tarinfo.isdir():
#    2275         # For directories, delay setting attributes until later,
#    2276         # since permissions can interfere with extraction and
#    2277         # extracting contents can reset mtime.
#    2278         directories.append(tarinfo)
# -> 2279     self._extract_one(tarinfo, path, set_attrs=not tarinfo.isdir(),
#    2280                       numeric_owner=numeric_owner)
#    2282 # Reverse sort directories.
#    2283 directories.sort(key=lambda a: a.name, reverse=True)
#
# File ~/anaconda3/envs/tgb_env/lib/python3.9/tarfile.py:2346, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner)
#    2342     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2343                          set_attrs=set_attrs,
#    2344                          numeric_owner=numeric_owner)
#    2345 except OSError as e:
# -> 2346     self._handle_fatal_error(e)
#    2347 except ExtractError as e:
#    2348     self._handle_nonfatal_error(e)
#
# File ~/anaconda3/envs/tgb_env/lib/python3.9/tarfile.py:2342, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner)
#    2339 self._check("r")
#    2341 try:
# -> 2342     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2343                          set_attrs=set_attrs,
#    2344                          numeric_owner=numeric_owner)
#    2345 except OSError as e:
#    2346     self._handle_fatal_error(e)
#
# File ~/anaconda3/envs/tgb_env/lib/python3.9/tarfile.py:2425, in TarFile._extract_member(self, tarinfo, targetpath, set_attrs, numeric_owner)
#    2422     self._dbg(1, tarinfo.name)
#    2424 if tarinfo.isreg():
# -> 2425     self.makefile(tarinfo, targetpath)
#    2426 elif tarinfo.isdir():
#    2427     self.makedir(tarinfo, targetpath)
#
# File ~/anaconda3/envs/tgb_env/lib/python3.9/tarfile.py:2478, in TarFile.makefile(self, tarinfo, targetpath)
#    2476     target.truncate()
#    2477 else:
# -> 2478     copyfileobj(source, target, tarinfo.size, ReadError, bufsize)
#
# File ~/anaconda3/envs/tgb_env/lib/python3.9/tarfile.py:254, in copyfileobj(src, dst, length, exception, bufsize)
#     252     if len(buf) < bufsize:
#     253         raise exception("unexpected end of data")
# --> 254     dst.write(buf)
#     256 if remainder != 0:
#     257     buf = src.read(remainder)
#
# OSError: [Errno 28] No space left on device

# %% [markdown]
# # run trace.py

# %%
# Out:
# 2025-05-02 10:55:33,307 - INFO - Dataset: cadets
# 2025-05-02 10:55:33,307 - INFO - Read configuration file: ./configs/cadets/cadets_e3_exec_all.ini
# 2025-05-02 10:55:33,307 - INFO - Reading metadata
# 2025-05-02 10:55:33,308 - INFO - Name: Cadets E3 All, Path: ./input_data/cadets/, Track: all, Outputpath: ./output_data/cadets/darpa_cadets/
# 2025-05-02 10:55:33,308 - INFO - Skip Events: ['lsof', 'python2.7', 'find', 'vmstat', 'top', 'pkg', 'sleep', 'bash', 'date', 'sh', 'local', 'ipfstat', 'procstat', 'mlock', 'qmgr', 'makewhatis'], Keep Events: ['EVENT_EXECUTE', 'EVENT_RENAME', 'EVENT_SENDTO', 'EVENT_RECVFROM', 'EVENT_WRITE', 'EVENT_READ', 'EVENT_MODIFY_FILE_ATTRIBUTES', 'EVENT_RENAME', 'EVENT_RECVMSG'], GT Metas: ['./configs/cadets/darpa-cadets-00_gt_meta.yaml', './configs/cadets/darpa-cadets-01_gt_meta.yaml', './configs/cadets/darpa-cadets-02_gt_meta.yaml', './configs/cadets/darpa-cadets-02_gt_meta_2.yaml']
# 2025-05-02 10:55:33,308 - INFO - Getting regex expressions
# 2025-05-02 10:55:33,308 - INFO - Regex expression added: uuid - uuid\":\"(.*?)\"
# 2025-05-02 10:55:33,308 - INFO - Regex expression added: src - subject\":{\"com.bbn.tc.schema.avro.cdm18.UUID\":\"(.*?)\"}
# 2025-05-02 10:55:33,309 - INFO - Regex expression added: dst1 - predicateObject\":{\"com.bbn.tc.schema.avro.cdm18.UUID\":\"(.*?)\"}
# 2025-05-02 10:55:33,309 - INFO - Regex expression added: dst2 - predicateObject2\":{\"com.bbn.tc.schema.avro.cdm18.UUID\":\"(.*?)\"}
# 2025-05-02 10:55:33,309 - INFO - Regex expression added: type - type\":\"(.*?)\"
# 2025-05-02 10:55:33,309 - INFO - Regex expression added: time - timestampNanos\":(.*?),
# 2025-05-02 10:55:33,309 - INFO - Regex expression added: exec - \"exec\":\"(.*?)\",
# 2025-05-02 10:55:33,310 - INFO - Regex expression added: path - \"predicateObjectPath\":{\"string\":\"(.*?)\"
# 2025-05-02 10:55:33,310 - INFO - Regex expression added: ip - \"address\":\"(.*?)\"
# 2025-05-02 10:55:33,310 - INFO - Regex expression added: port - \"port\":(.*?)
# 2025-05-02 10:55:33,310 - INFO - Getting regex expressions
# 2025-05-02 10:55:33,310 - INFO - Regex expression added: host - com.bbn.tc.schema.avro.cdm18.Host
# 2025-05-02 10:55:33,310 - INFO - Regex expression added: timemarker - com.bbn.tc.schema.avro.cdm18.TimeMarker
# 2025-05-02 10:55:33,310 - INFO - Regex expression added: startmarker - com.bbn.tc.schema.avro.cdm18.StartMarker
# 2025-05-02 10:55:33,311 - INFO - Regex expression added: unitdependency - com.bbn.tc.schema.avro.cdm18.UnitDependency
# 2025-05-02 10:55:33,311 - INFO - Regex expression added: endmarker - com.bbn.tc.schema.avro.cdm18.EndMarker
# 2025-05-02 10:55:33,311 - INFO - Regex expression added: memoryobject - com.bbn.tc.schema.avro.cdm18.MemoryObject
# 2025-05-02 10:55:33,311 - INFO - Regex expression added: unnamedpipeobject - com.bbn.tc.schema.avro.cdm18.UnnamedPipeObject
# 2025-05-02 10:55:33,311 - INFO - Getting regex expressions
# 2025-05-02 10:55:33,312 - INFO - Regex expression added: event - com.bbn.tc.schema.avro.cdm18.Event
# 2025-05-02 10:55:33,312 - INFO - Regex expression added: netflowobject - com.bbn.tc.schema.avro.cdm18.NetFlowObject
# 2025-05-02 10:55:33,317 - INFO - Ready for parsing
# 2025-05-02 10:55:33,600 - INFO - Parsing data based on configuration
# 2025-05-02 10:56:07,637 - INFO - Nodes processed: 2798482
# 2025-05-02 10:56:07,637 - INFO - Number of read lines in nodes preprocessing: 44404339
# 2025-05-02 10:56:07,637 - INFO - Number of nodes: 3053444
# 2025-05-02 10:56:07,638 - INFO - Therefore 254962 nodes were excluded
# 2025-05-02 10:56:31,714 - INFO - Edges processed in File: ./input_data/cadets/ta1-cadets-e3-official.json
# 2025-05-02 10:56:55,885 - INFO - Edges processed in File: ./input_data/cadets/ta1-cadets-e3-official.json.1
# 2025-05-02 10:57:15,102 - INFO - Edges processed in File: ./input_data/cadets/ta1-cadets-e3-official.json.2
# 2025-05-02 10:57:39,959 - INFO - Edges processed in File: ./input_data/cadets/ta1-cadets-e3-official-1.json
# 2025-05-02 10:58:06,258 - INFO - Edges processed in File: ./input_data/cadets/ta1-cadets-e3-official-1.json.1
# 2025-05-02 10:58:32,402 - INFO - Edges processed in File: ./input_data/cadets/ta1-cadets-e3-official-1.json.2
# 2025-05-02 10:58:58,849 - INFO - Edges processed in File: ./input_data/cadets/ta1-cadets-e3-official-1.json.3
# 2025-05-02 10:59:09,839 - INFO - Edges processed in File: ./input_data/cadets/ta1-cadets-e3-official-1.json.4
# 2025-05-02 10:59:35,869 - INFO - Edges processed in File: ./input_data/cadets/ta1-cadets-e3-official-2.json
# 2025-05-02 10:59:53,894 - INFO - Edges processed in File: ./input_data/cadets/ta1-cadets-e3-official-2.json.1
# 2025-05-02 10:59:53,895 - INFO - Number of events: 41350895
# 2025-05-02 10:59:53,895 - INFO - Processed lines for edges: 44404339
# 2025-05-02 10:59:53,895 - INFO - Number of correct events: 4461709
# 2025-05-02 10:59:53,896 - INFO - therefore 36889186 events were excluded
# 2025-05-02 10:59:53,896 - INFO - Number of unique edges: 289064
# 2025-05-02 10:59:53,896 - INFO - Therefore 4172645 edges were excluded from the correct events
# 2025-05-02 10:59:53,896 - INFO - All edges processed
# 2025-05-02 10:59:53,896 - INFO - Output eventlist file closed
# 2025-05-02 10:59:53,897 - INFO - Converting ThreatTrace data to DyGraph format
# 2025-05-02 10:59:54,564 - INFO - Some Statistics:
# 2025-05-02 10:59:54,564 - INFO -   Number of nodes: 199538
# 2025-05-02 10:59:54,565 - INFO -   Number of edge types: 8
# 2025-05-02 10:59:54,565 - INFO -   Number of exec types: 119
# 2025-05-02 10:59:54,565 - INFO -   Number of source and destination types: 4
# 2025-05-02 10:59:54,565 - INFO -   Number of edges: 289064
# 2025-05-02 10:59:54,565 - INFO -   Number of Anomal edge labels: 441
# 2025-05-02 10:59:54,566 - INFO -   Number of Normal edge labels: 288623
# 2025-05-02 10:59:54,566 - INFO - Output file closed: ./output_data/cadets/darpa_cadets/cadets.csv
# 2025-05-02 10:59:55,589 - INFO - Unique edge list written to file: ./output_data/cadets/darpa_cadets/cadets_unique.csv
# 2025-05-02 10:59:55,590 - INFO - Unique edge list written to file: ./output_data/cadets/darpa_cadets/cadets_normal_unique.csv
# 2025-05-02 10:59:55,603 - INFO - Node list written to file: ./output_data/cadets/darpa_cadets/cadets_normal_unique_nodelist.csv
# Len of df_output: 84763
# Len of df_output_normal: 84762
# Len of df_output after drop: 9187
# Len of df_output_normal after drop: 9186

# %%
import shutil

old_path = "./output_data/trace/darpa_trace/events_tgb_mapped.csv"
new_path = "./output_data/trace/darpa_trace/darpa-trace.csv"

if os.path.exists(old_path):
    shutil.copy(old_path, new_path)
    logging.info(f"Copied {old_path} to {new_path}")
else:
    logging.warning(f"File {old_path} does not exist")
# Out:
# 2025-05-02 16:23:12,184 - INFO - Copied ./output_data/trace/darpa_trace/events_tgb_mapped.csv to ./output_data/trace/darpa_trace/darpa-trace.csv
